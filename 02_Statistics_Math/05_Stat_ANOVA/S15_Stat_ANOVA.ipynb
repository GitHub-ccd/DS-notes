# %% [markdown]
# # Section 15 — ANOVA & Statistical Power
#
# ANOVA extends t-tests to multiple groups. Statistical power determines whether your study is large enough to detect an effect — critical for A/B test design.
#
# ---
#
# ## 1. Introduction
# - [Statistical Power & ANOVA Section Intro](./S15_08_statistical_power_anova_introduction.ipynb)
#
# ---
#
# ## 2. Statistical Power
# - [Statistical Power](./S15_11_statistical_power.ipynb) · [Lab](./S15_10_statistical_power_lab.ipynb)
# - [Effect Sizes, p-Values and Power Lab](./S15_03_effect_sizes_pvalues_and_power_lab.ipynb)
#
# ---
#
# ## 3. ANOVA
# - [ANOVA](./S15_02_anova.ipynb) · [Lab](./S15_01_anova_lab.ipynb)
# - [Welch's t-Test](./S15_13_welchs_ttest.ipynb) · [Lab](./S15_12_welchs_ttest_lab.ipynb)
#
# ---
#
# ## 4. Non-Parametric Tests
# - [Kolmogorov-Smirnov Test](./S15_05_kolmogorov_smirnov_test.ipynb) · [Lab](./S15_06_komogorov_smirnov_test_lab.ipynb)
#
# ---
#
# ## 5. Multiple Comparisons
# - [The Multiple Comparisons Problem](./S15_07_multiple_comparisons_problem.ipynb)
#
# ---
#
# ## 6. Measurement & Metrics
# - [Goodhart's Law and Metric Tracking](./S15_04_goodharts_law_and_metric_tracking.ipynb)
#
# ---
#
# ## 7. Recap
# - [Statistical Power & ANOVA Section Recap](./S15_09_statistical_power_anova_recap.ipynb)
