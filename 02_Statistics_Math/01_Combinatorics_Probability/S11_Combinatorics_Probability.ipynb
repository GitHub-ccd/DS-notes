# %% [markdown]
# # Section 11 — Combinatorics & Probability
#
# Foundational probability theory. These concepts underpin Bayesian reasoning, statistical tests, and model evaluation throughout the curriculum.
#
# ---
#
# ## 1. Introduction
# - [Probability Section Intro](./S11_14_probability_section_intro.ipynb)
# - [What is Probability](./S11_13_probability_introduction.ipynb)
#
# ---
#
# ## 2. Sets
# - [Introduction to Sets](./S11_08_intro_to_sets.ipynb) · [Lab](./S11_07_intro_to_sets_lab.ipynb)
#
# ---
#
# ## 3. Introduction to Probability
# - [Intro to Probability](./S11_06_intro_to_probability.ipynb) · [Lab](./S11_05_intro_to_probability_lab.ipynb)
#
# ---
#
# ## 4. Counting — Permutations & Combinations
# - [Permutations and Factorials](./S11_12_permutations_and_factorials.ipynb) · [Lab](./S11_11_permutations_and_factorials_lab.ipynb)
# - [Combinations](./S11_02_combinations.ipynb) · [Lab](./S11_01_combinations_lab.ipynb)
#
# ---
#
# ## 5. Conditional Probability
# - [Conditional Probability](./S11_04_conditional_probability.ipynb) · [Lab](./S11_03_conditional_probability_lab.ipynb)
# - [Law of Total Probability](./S11_10_law_of_total_probability.ipynb) · [Lab](./S11_09_law_of_total_probability_lab.ipynb)
# - [Probability Simulations Lab](./S11_16_probability_simulations_lab.ipynb)
#
# ---
#
# ## 6. Recap
# - [Probability Section Recap](./S11_15_probability_section_recap.ipynb)
