# %% [markdown]
# # Section 12 — Statistical Distributions
#
# Understanding how data is distributed is prerequisite to every statistical test and ML model. These distributions appear constantly in practice.
#
# ---
#
# ## 1. Introduction
# - [Distributions Section Intro](./S12_05_distributions_section_intro.ipynb)
# - [Statistical Distributions Use Cases](./S12_18_stat_distributions_use_cases.ipynb)
#
# ---
#
# ## 2. Discrete Distributions
# - [Probability Mass Function (PMF)](./S12_13_probability_mass_function.ipynb) · [Lab](./S12_12_probability_mass_function_lab.ipynb)
# - [Bernoulli & Binomial Distribution](./S12_02_bernoulli_and_binomial_distribution.ipynb) · [Lab](./S12_01_bernoulli_and_binomial_distribution_lab.ipynb)
#
# ---
#
# ## 3. Continuous Distributions
# - [Probability Density Function (PDF)](./S12_11_probability_density_function.ipynb)
# - [Cumulative Distribution Function (CDF)](./S12_04_cumulative_distribution_function.ipynb) · [Lab](./S12_03_cumulative_distribution_function_lab.ipynb)
# - [Normal Distribution](./S12_08_normal_distribution.ipynb) · [Lab](./S12_07_normal_distribution_lab.ipynb)
# - [Skewness and Kurtosis](./S12_15_skewness_and_kurtosis.ipynb) · [Lab](./S12_14_skewness_and_kurtosis_lab.ipynb)
#
# ---
#
# ## 4. Standardisation & z-Tests
# - [Standard Normal Distribution](./S12_17_standard_normal_distribution.ipynb) · [Lab](./S12_16_standard_normal_distribution_lab.ipynb)
# - [z-Score and p-Value](./S12_19_z_score_p_value.ipynb)
# - [One-Sample z-Test](./S12_10_one_sample_z_test.ipynb) · [Lab](./S12_09_one_sample_z_test_lab.ipynb)
#
# ---
#
# ## 5. Recap
# - [Distributions Section Recap](./S12_06_distributions_section_recap.ipynb)
