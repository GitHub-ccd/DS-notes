# %% [markdown]
# # Section 18 — Simple Linear Regression
#
# OLS regression is the foundation of all supervised learning. Understanding it deeply — assumptions, diagnostics, p-values — makes every more complex model easier to interpret.
#
# ---
#
# ## 1. Introduction
# - [Linear Regression Section Intro](./S18_04_linear_regression_section_intro.ipynb)
# - [Statistical Learning Theory](./S18_15_stat_learning_theory.ipynb)
#
# ---
#
# ## 2. Simple OLS
# - [Simple Linear Regression](./S18_14_simple_linear_regression.ipynb) · [Lab](./S18_13_simple_linear_regression_lab.ipynb)
# - [Coefficient of Determination (R²)](./S18_02_coefficient_of_determination.ipynb) · [Lab](./S18_01_coefficient_of_determination_lab.ipynb)
# - [Complete Regression Lab](./S18_03_complete_regression_lab.ipynb)
#
# ---
#
# ## 3. Assumptions & Diagnostics
# - [Regression Assumptions](./S18_09_regression_assumptions.ipynb)
# - [OLS in Statsmodels](./S18_08_ols_statsmodels.ipynb) · [Lab](./S18_07_ols_statsmodels_lab.ipynb)
# - [OLS Regression Diagnostics](./S18_06_ols_regression_diagnostics.ipynb)
# - [Significance and p-Value](./S18_12_significance_p_value.ipynb)
#
# ---
#
# ## 4. Project — Boston Housing
#
# > ⚠️ **LEGACY NOTE (2026):** Both labs below use the Boston Housing dataset, which was **removed from sklearn v1.2** due to ethical concerns. The dataset is still in the local `data/` folder and the regression exercises remain valid — just be aware of the provenance. For new regression projects use **California Housing** (`sklearn.datasets.fetch_california_housing`) or **Ames Housing** (`fetch_openml('house_prices')`).
#
# - [Regression with Boston Housing — Lab](./S18_10_regression_boston_lab.ipynb)
# - [Regression with Boston Housing — Solutions](./S18_11_regression_boston_lab.ipynb)
#
# ---
#
# ## 5. Recap
# - [Linear Regression Section Recap](./S18_05_linear_regression_section_recap.ipynb)
