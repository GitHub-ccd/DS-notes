# %% [markdown]
# # Section 20 — Linear Model Extensions
#
# Extends linear regression beyond straight lines: interaction terms, polynomial fits, and the bias-variance tradeoff — the central tension in all of ML.
#
# ---
#
# ## 1. Introduction
# - [Extensions to Linear Models Intro](./S20_03_extensions_to_linear_models_intro.ipynb)
#
# ---
#
# ## 2. Interaction Terms
# - [Interaction Terms](./S20_06_interaction_terms.ipynb) · [Lab](./S20_05_interaction_terms_lab.ipynb)
#
# ---
#
# ## 3. Polynomial Regression
# - [Polynomial Regression](./S20_08_polynomial_regression.ipynb) · [Lab](./S20_07_polynomial_regression_lab.ipynb)
#
# ---
#
# ## 4. Bias-Variance Tradeoff
# - [Bias-Variance Tradeoff](./S20_02_bias_variance_trade_off.ipynb) · [Lab](./S20_01_bias_variance_trade_off_lab.ipynb)
#
# ---
#
# ## 5. Recap
# - [Extensions to Linear Models Recap](./S20_04_extensions_to_linear_models_recap.ipynb)
