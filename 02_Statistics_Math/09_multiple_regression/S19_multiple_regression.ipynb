# %% [markdown]
# # Section 19 — Multiple Regression & Model Validation
#
# Extends OLS to multiple features and introduces the full model-building workflow: preprocessing, validation, and persistence.
#
# ---
#
# ## 1. Introduction
# - [Regression Introduction](./S19_18_regression_introduction.ipynb)
#
# ---
#
# ## 2. Multiple Linear Regression
# - [Multiple Linear Regression](./S19_15_multiple_linear_regression.ipynb)
# - [Multiple Linear Regression in Statsmodels](./S19_14_multiple_linear_regression_in_statsmodels.ipynb) · [Lab](./S19_16_multiple_linear_regression_statsmodels_lab.ipynb)
#
# ---
#
# ## 3. Feature Engineering
# - [Dealing with Categorical Variables](./S19_05_dealing_with_categorical_variables.ipynb) · [Lab](./S19_04_dealing_with_categorical_variables_lab.ipynb)
# - [Multicollinearity of Features](./S19_13_multicollinearity_of_features.ipynb) · [Lab](./S19_12_multicollinearity_of_features_lab.ipynb)
# - [Log Transformations](./S19_09_log_transformations.ipynb)
# - [Feature Scaling and Normalization](./S19_07_feature_scaling_and_normalization.ipynb) · [Lab](./S19_06_feature_scaling_and_normalization_lab.ipynb)
#
# ---
#
# ## 4. Model Evaluation
# - [Inference vs Prediction](./S19_08_inference_vs_prediction.ipynb)
# - [Model Fit in Linear Regression](./S19_11_model_fit_linear_regression.ipynb) · [Lab](./S19_10_model_fit_linear_regression_lab.ipynb)
# - [Regression Model Validation](./S19_21_regression_model_validation.ipynb) · [Lab](./S19_20_regression_model_validation_lab.ipynb)
# - [Cross-Validation](./S19_02_cross_validation.ipynb) · [Lab](./S19_01_cross_validation_lab.ipynb)
#
# ---
#
# ## 5. Model Persistence
# - [Pickle](./S19_17_pickle.ipynb) — see security note inside
#
# > **2026 note:** For sklearn models, prefer **joblib** over raw pickle — it's faster for large numpy arrays and is sklearn's own recommendation. `joblib.dump(model, 'model.joblib')` / `joblib.load('model.joblib')`. For production, consider **ONNX** (framework-agnostic) or **MLflow** model registry.
#
# ---
#
# ## 6. Process
# - [Data Science Processes](./S19_03_data_science_processes.ipynb)
#
# ---
#
# ## 7. Recap
# - [Regression Model Eval Recap](./S19_19_regression_model_eval_recap.ipynb)
