# %% [markdown]
# # Section 1 — Data Science Introduction
#
# Python fundamentals, the data science process, and first steps with data visualization.
#
# ---
#
# ## 1. What is Data Science
# - [Problems Data Science Can Solve](./S1_20_problems_data_science_can_solve.ipynb)
# - [The Data Science Process](./S1_24_the_data_science_process.ipynb)
#
# ---
#
# ## 2. Python Fundamentals
# - [Variable Assignment](./S1_25_variable_assignment_intro.ipynb) · [Lab](./S1_26_variable_assignment_lab.ipynb)
# - [Strings](./S1_23_strings.ipynb) · [Lab](./S1_22_strings_lab.ipynb)
# - [Floats, Ints & Booleans](./S1_12_floats_ints_booleans.ipynb) · [Mixed Types Lab](./S1_21_strings_floats_ints_lab.ipynb)
# - [Lists](./S1_17_lists.ipynb) · [Lab](./S1_16_lists_lab.ipynb)
# - [Dictionaries](./S1_10_dictionaries.ipynb) · [Lab](./S1_09_dictionaries_lab.ipynb)
#
# ---
#
# ## 3. Control Flow
# - [Conditionals](./S1_04_conditionals.ipynb) · [Lab](./S1_03_conditionals_lab.ipynb)
# - [Looping Over Collections](./S1_19_looping_over_collections.ipynb) · [Lab](./S1_18_looping_over_collections_lab.ipynb)
#
# ---
#
# ## 4. First Data Visualization
# - [Data Visualization Intro](./S1_08_data_viz.ipynb) · [Lab](./S1_07_data_viz_lab.ipynb)
# - [First Code-Along (Lego sets)](./S1_11_first_codealong.ipynb)
#
# ---
#
# ## 5. Project
# - [Analyzing Macbeth](./S1_01_analyzing_macbeth_project.ipynb)
