# %% [markdown]
# # Section 9 — JSON & APIs
#
# JSON is the universal data format of the web and the standard format for API responses. In 2026, working with APIs means working with REST APIs generally — and increasingly with **LLM APIs** (Anthropic, OpenAI) specifically.
#
# ---
#
# ## 1. JSON Fundamentals
# - [JSON & APIs Introduction](./S9_03_json_apis_intro.ipynb)
# - [Working with JSON](./S9_05_json.ipynb) · [Lab](./S9_04_json_lab.ipynb)
# - [Working with Known JSON Schemas](./S9_07_working_with_known_json_schemas.ipynb) · [Lab](./S9_06_working_with_known_json_schemas_lab.ipynb)
# - [Exploring & Transforming JSON Schemas](./S9_02_exploring_and_transforming_json_schemas.ipynb) · [Lab](./S9_01_exploring_and_transforming_json_schemas_lab.ipynb)
#
# ---
#
# ## 2. REST APIs
#
# Core pattern: send an HTTP request with `requests`, get JSON back, parse it.
#
# ```python
# import requests
# response = requests.get('https://api.example.com/data', headers={'Authorization': 'Bearer YOUR_KEY'})
# data = response.json()  # dict/list
# ```
#
# Key concepts covered in the notebooks above: HTTP verbs (GET/POST), status codes, authentication (API keys, OAuth), rate limiting, pagination.
#
# ---
#
# ## 3. LLM APIs ← 2026 Priority
#
# Calling LLM APIs is now one of the most common API patterns for DS/ML practitioners. The pattern is similar to any REST API but with specific conventions for messages, roles, and structured outputs.
#
# - [LLM APIs — Anthropic & OpenAI patterns](./S9_08_llm_apis.ipynb) ← **new**
#
# Topics covered:
# - Anthropic Claude API (messages API)
# - Structured outputs / JSON mode
# - Streaming responses
# - Tool use (function calling)
# - Practical patterns: summarisation, extraction, classification
