# %% [markdown]
# # Graph Theory
#
# [dsc-network-introduction-onl01-dtsc-ft-030220/index.ipynb](./dsc-network-introduction-onl01-dtsc-ft-030220/index.ipynb)
#
# [dsc-intro-graph-theory-onl01-dtsc-ft-030220/index.ipynb](./dsc-intro-graph-theory-onl01-dtsc-ft-030220/index.ipynb)
#
# [dsc-networkX-intro-onl01-dtsc-ft-030220/index.ipynb](./dsc-networkX-intro-onl01-dtsc-ft-030220/index.ipynb)
# NetworkX — Python graph library for building and analysing graphs
#
# [dsc-networkX-intro-lab-onl01-dtsc-ft-030220/index.ipynb](./dsc-networkX-intro-lab-onl01-dtsc-ft-030220/index.ipynb)
#
# [dsc-graph-theory-shortest-path-onl01-dtsc-ft-030220/index.ipynb](./dsc-graph-theory-shortest-path-onl01-dtsc-ft-030220/index.ipynb)
# Dijkstra's algorithm, BFS/DFS
#
# [dsc-graph-theory-shortest-path-lab-onl01-dtsc-ft-030220/index.ipynb](./dsc-graph-theory-shortest-path-lab-onl01-dtsc-ft-030220/index.ipynb)
#
# [dsc-node-centrality-onl01-dtsc-ft-030220/index.ipynb](./dsc-node-centrality-onl01-dtsc-ft-030220/index.ipynb)
# Degree, betweenness, closeness, eigenvector centrality
#
# [dsc-node-centrality-lab-onl01-dtsc-ft-030220/index.ipynb](./dsc-node-centrality-lab-onl01-dtsc-ft-030220/index.ipynb)
#
# [dsc-network-clustering-onl01-dtsc-ft-030220/index.ipynb](./dsc-network-clustering-onl01-dtsc-ft-030220/index.ipynb)
#
# [dsc-network-clustering-lab-onl01-dtsc-ft-030220/index.ipynb](./dsc-network-clustering-lab-onl01-dtsc-ft-030220/index.ipynb)
#
# [dsc-network-community-detection-lab-onl01-dtsc-ft-030220/index.ipynb](./dsc-network-community-detection-lab-onl01-dtsc-ft-030220/index.ipynb)
#
# [dsc-network-recommendation-systems-onl01-dtsc-ft-030220/index.ipynb](./dsc-network-recommendation-systems-onl01-dtsc-ft-030220/index.ipynb)
# Graph-based recommendation: collaborative filtering via bipartite graphs
#
# [dsc-network-recomendation-systems-lab-onl01-dtsc-ft-030220/index.ipynb](./dsc-network-recomendation-systems-lab-onl01-dtsc-ft-030220/index.ipynb)
#
# [dsc-networks-recap-onl01-dtsc-ft-030220/index.ipynb](./dsc-networks-recap-onl01-dtsc-ft-030220/index.ipynb)
#
# ---
#
# > **2026 context:** NetworkX-based graph analysis remains relevant for network science and graph algorithms. For **machine learning on graphs**, the field has moved to **Graph Neural Networks (GNNs)**:
# >
# > - **PyTorch Geometric** (`torch_geometric`) — the dominant GNN library; implements GCN, GAT, GraphSAGE, and hundreds of variants
# > - **DGL** (Deep Graph Library) — alternative to PyG, supports both PyTorch and MXNet backends
# >
# > GNNs are used for: molecular property prediction (drug discovery), fraud detection in transaction graphs, social network analysis, knowledge graphs, and recommendation systems. NetworkX is still used for graph construction and classical algorithms; PyG/DGL are used when you want to learn representations from graph structure.
