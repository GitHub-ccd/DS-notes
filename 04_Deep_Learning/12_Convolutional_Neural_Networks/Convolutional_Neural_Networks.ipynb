# %% [markdown]
# # Convolutional Neural Networks (CNN)
#
# [dsc-cnn-intro-onl01-dtsc-ft-030220/index.ipynb](./dsc-cnn-intro-onl01-dtsc-ft-030220/index.ipynb)
#
# [dsc-convolutional-neural-networks-onl01-dtsc-ft-030220/index.ipynb](./dsc-convolutional-neural-networks-onl01-dtsc-ft-030220/index.ipynb)
# - What a convolution is in the context of CNNs
# - Convolutions on RGB images
# - Pooling layers (max pooling, average pooling)
# - Padding in convolution layers
#
# [dsc-convolutional-neural-networks-codealong-onl01-dtsc-ft-030220/index.ipynb](./dsc-convolutional-neural-networks-codealong-onl01-dtsc-ft-030220/index.ipynb)
# - Loading images with Keras ImageDataGenerator
# - Data augmentation (flips, rotations, zoom)
# - Building a CNN in Keras end-to-end
#
# [dsc-building-a-cnn-from-scratch-onl01-dtsc-ft-030220/index.ipynb](./dsc-building-a-cnn-from-scratch-onl01-dtsc-ft-030220/index.ipynb)
#
# [dsc-visualizing-intermediate-activations-onl01-dtsc-ft-030220/index.ipynb](./dsc-visualizing-intermediate-activations-onl01-dtsc-ft-030220/index.ipynb)
#
# [dsc-visualizing-activation-functions-lab-onl01-dtsc-ft-030220/index.ipynb](./dsc-visualizing-activation-functions-lab-onl01-dtsc-ft-030220/index.ipynb)
#
# [dsc-cnn-recap-onl01-dtsc-ft-030220/index.ipynb](./dsc-cnn-recap-onl01-dtsc-ft-030220/index.ipynb)
#
# ---
#
# > **2026 context:** CNNs remain the standard for tasks where **spatial locality** matters and data volume is too small for transformers. However, **Vision Transformers (ViT)** now match or beat CNNs on image classification benchmarks when enough data is available. In practice:
# >
# > - **Custom CNNs** (as built here) — good for learning; rarely built from scratch in production
# > - **Pretrained CNNs** (ResNet, EfficientNet, ConvNeXt via HuggingFace or `torchvision`) — the standard starting point for image tasks; see [Transfer_Learning](../Transfer_Learning/Transfer_Learning.ipynb)
# > - **Vision Transformers (ViT, CLIP)** — use when you have large datasets or need image-text alignment
# >
# > In PyTorch: `torchvision.models` provides pretrained ResNet, EfficientNet, ViT. HuggingFace `transformers` provides ViT, CLIP, and DINO.
