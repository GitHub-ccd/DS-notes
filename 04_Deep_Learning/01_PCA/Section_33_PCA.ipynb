# %% [markdown]
# # Section 33 — Principal Component Analysis (PCA)
#
# [S33_13_unsupervised_learning.ipynb](./S33_13_unsupervised_learning.ipynb)
# Unsupervised vs supervised learning — when labels aren't available
#
# [S33_09_pca_introduction.ipynb](./S33_09_pca_introduction.ipynb)
# PCA use cases, explained variance, choosing number of components
#
# [S33_02_curse_of_dimensionality.ipynb](./S33_02_curse_of_dimensionality.ipynb)
# Sparsity grows exponentially with dimensions — why high-D spaces are problematic
#
# [S33_01_curse_of_dimensionality_lab.ipynb](./S33_01_curse_of_dimensionality_lab.ipynb)
#
# [S33_08_pca_in_scikitlearn.ipynb](./S33_08_pca_in_scikitlearn.ipynb)
# - How PCA works at a high level
# - `sklearn.decomposition.PCA` — fit, transform, explained variance ratio
# - Determining optimal `n_components` from scree plot
#
# [S33_07_pca_in_scikitlearn_lab.ipynb](./S33_07_pca_in_scikitlearn_lab.ipynb)
# PCA steps: center → covariance matrix → eigenvectors → project
#
# [S33_05_pca_and_pipelines.ipynb](./S33_05_pca_and_pipelines.ipynb)
# PCA inside a sklearn Pipeline — dimensionality reduction before a classifier
#
# [S33_06_pca_covariance_matrix_eigendecomp.ipynb](./S33_06_pca_covariance_matrix_eigendecomp.ipynb)
# Covariance matrix, eigenvalues, eigenvectors — the linear algebra behind PCA
#
# [S33_12_performing_principal_component_analysis.ipynb](./S33_12_performing_principal_component_analysis.ipynb)
#
# [S33_10_pca_numpy_lab.ipynb](./S33_10_pca_numpy_lab.ipynb)
#
# [S33_04_pca_and_digital_image_processing.ipynb](./S33_04_pca_and_digital_image_processing.ipynb)
# PCA for image compression — eigenfaces example
#
# [S33_03_pca_and_digital_image_processing_lab.ipynb](./S33_03_pca_and_digital_image_processing_lab.ipynb)
#
# [S33_11_pca_summary.ipynb](./S33_11_pca_summary.ipynb)
