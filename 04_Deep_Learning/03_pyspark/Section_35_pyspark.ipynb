# %% [markdown]
# # Section 35 — PySpark & Big Data
#
# [S35_08_spark_introduction.ipynb](./S35_08_spark_introduction.ipynb)
# Apache Spark overview — in-memory distributed computing
#
# [S35_02_big_data_introduction.ipynb](./S35_02_big_data_introduction.ipynb)
# The 3 V's: Volume, Velocity, Variety — when standard tools stop scaling
#
# [S35_05_parallel_and_distributed_computing_with_mapreduce.ipynb](./S35_05_parallel_and_distributed_computing_with_mapreduce.ipynb)
# MapReduce paradigm, distributed vs parallel processing, word count example
#
# [S35_01_big_data_analytics_apache_spark.ipynb](./S35_01_big_data_analytics_apache_spark.ipynb)
# Spark's role in big data analytics, RDDs, Spark ecosystem
#
# [S35_07_spark_docker_installation.ipynb](./S35_07_spark_docker_installation.ipynb)
# Running Spark locally via Docker
#
# [S35_06_resilient_distributed_datasets_rdd_lab.ipynb](./S35_06_resilient_distributed_datasets_rdd_lab.ipynb)
#
# [S35_10_word_count_with_map_reduce_lab.ipynb](./S35_10_word_count_with_map_reduce_lab.ipynb)
#
# [S35_04_machine_learning_with_spark.ipynb](./S35_04_machine_learning_with_spark.ipynb)
# MLlib — Spark's built-in ML library
#
# [S35_03_machine_learning_with_spark_lab.ipynb](./S35_03_machine_learning_with_spark_lab.ipynb)
#
# [S35_09_spark_section_recap.ipynb](./S35_09_spark_section_recap.ipynb)
#
# ---
#
# > **2026 context:** PySpark on a local Docker container is fine for learning, but in production Spark now runs almost exclusively on managed cloud platforms: **Databricks** (available on AWS, Azure, and GCP — the most popular Spark platform), **AWS EMR**, **Azure HDInsight/Synapse**, or **GCP Dataproc**. Databricks adds the Delta Lake format, Unity Catalog, and MLflow integration on top of Spark — making it the de-facto standard for large-scale ML pipelines. If you're working with Spark in a professional context, expect to use Databricks rather than a self-managed cluster.
