# %% [markdown]
# # Section 42 — Tuning Neural Networks
#
# [S42_02_tuning_neural_networks_intro.ipynb](./S42_02_tuning_neural_networks_intro.ipynb)
#
# [S42_07_tuning_neural_networks_with_regularization.ipynb](./S42_07_tuning_neural_networks_with_regularization.ipynb)
# L1/L2 weight regularisation and dropout — combating overfitting
#
# [S42_06_tuning_neural_networks_with_regularization_lab.ipynb](./S42_06_tuning_neural_networks_with_regularization_lab.ipynb)
#
# [S42_05_tuning_neural_networks_with_normalization.ipynb](./S42_05_tuning_neural_networks_with_normalization.ipynb)
# Batch normalisation — stabilising activations across layers
#
# [S42_04_tuning_neural_networks_with_normalization_lab.ipynb](./S42_04_tuning_neural_networks_with_normalization_lab.ipynb)
#
# [S42_01_tuning_neural_networks_from_start_to_finish_lab.ipynb](./S42_01_tuning_neural_networks_from_start_to_finish_lab.ipynb)
# End-to-end: architecture choice, regularisation, normalisation, hyperparameter search
#
# [S42_03_tuning_neural_networks_recap.ipynb](./S42_03_tuning_neural_networks_recap.ipynb)
#
# ---
#
# > **2026 context:** The regularisation and normalisation concepts here are timeless — they apply in PyTorch exactly as in Keras. Modern additions worth knowing:
# >
# > - **Learning rate schedulers** (`torch.optim.lr_scheduler`, Keras `ReduceLROnPlateau`) — decaying or cycling the learning rate during training often outperforms a fixed rate
# > - **Early stopping** with patience — standard in both frameworks
# > - **Gradient clipping** — important for RNNs and Transformers to prevent exploding gradients
# > - **Hyperparameter search:** `keras-tuner`, **Optuna** (framework-agnostic, widely used), or **Ray Tune** for large-scale search
# > - **Layer normalisation** (LayerNorm) — preferred over BatchNorm in Transformer architectures
