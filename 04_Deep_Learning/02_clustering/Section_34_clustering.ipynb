# %% [markdown]
# # Section 34 — Clustering
#
# [S34_01_clustering_intro.ipynb](./S34_01_clustering_intro.ipynb)
#
# [S34_07_k_means_clustering.ipynb](./S34_07_k_means_clustering.ipynb)
# K-means algorithm:
# 1. Select k initial seeds
# 2. Assign each point to nearest centroid
# 3. Recompute centroids
# 4. Repeat until stable
# Evaluation: inertia, silhouette score, elbow plot
#
# [S34_06_k_means_clustering_lab.ipynb](./S34_06_k_means_clustering_lab.ipynb)
#
# [S34_05_hierarchical_agglomerative_clustering.ipynb](./S34_05_hierarchical_agglomerative_clustering.ipynb)
# Bottom-up merging — dendrogram, linkage methods
#
# [S34_04_hierarchical_agglomerative_clustering_codealong.ipynb](./S34_04_hierarchical_agglomerative_clustering_codealong.ipynb)
#
# [S34_03_common_problems_with_clustering.ipynb](./S34_03_common_problems_with_clustering.ipynb)
# Sensitivity to initialisation, scaling, and outliers
#
# [S34_09_market_segmentation_clustering.ipynb](./S34_09_market_segmentation_clustering.ipynb)
# Real-world application: customer segmentation
#
# [S34_08_market_segmentation_clustering_lab.ipynb](./S34_08_market_segmentation_clustering_lab.ipynb)
#
# [S34_10_semi_supervised_learning_and_look_alike_models.ipynb](./S34_10_semi_supervised_learning_and_look_alike_models.ipynb)
# Using clustering to label unlabelled data; look-alike modelling
#
# [S34_02_clustering_recap.ipynb](./S34_02_clustering_recap.ipynb)
