# %% [markdown]
# # Section 43 — Cloud ML Platforms
#
# Productionising ML models on AWS, Azure, and GCP.
#
# ---
#
# ## AWS SageMaker
#
# [S43_03_productionizing_machine_learning_models_section_intro.ipynb](./S43_03_productionizing_machine_learning_models_section_intro.ipynb)
#
# [S43_01_data_science_and_machine_learning_engineering.ipynb](./S43_01_data_science_and_machine_learning_engineering.ipynb)
# DS vs ML Engineering — the productionisation gap
#
# [S43_06_the_aws_ecosystem.ipynb](./S43_06_the_aws_ecosystem.ipynb)
# S3, EC2, IAM, SageMaker — the core AWS services for ML
#
# [S43_02_introduction_to_aws_sagemaker.ipynb](./S43_02_introduction_to_aws_sagemaker.ipynb)
# SageMaker Studio, training jobs, built-in algorithms
#
# [S43_05_productionizing_models_with_sagemaker.ipynb](./S43_05_productionizing_models_with_sagemaker.ipynb)
# SageMaker endpoints — deploying a trained model as a REST API
#
# [S43_04_productionizing_machine_learning_models_section_recap.ipynb](./S43_04_productionizing_machine_learning_models_section_recap.ipynb)
#
# ---
#
# ## Microsoft Azure — Azure Machine Learning
#
# [S43_07_azure_ml.ipynb](./S43_07_azure_ml.ipynb)
# Azure ML Studio, pipelines, managed endpoints, MLflow integration
#
# ---
#
# ## Google Cloud Platform — Vertex AI
#
# [S43_08_gcp_vertex_ai.ipynb](./S43_08_gcp_vertex_ai.ipynb)
# Vertex AI AutoML, Pipelines, Model Registry, Workbench, Gemini integration
#
# ---
#
# > **2026 context:** AWS, Azure, and GCP each hold roughly 30% of the cloud ML market. In practice:
# > - **AWS SageMaker** — most mature ML platform; broadest set of managed algorithms; common in US enterprise
# > - **Azure ML** — dominant in Microsoft/Office365 shops; strong MLflow integration; good for hybrid (cloud + on-prem)
# > - **GCP Vertex AI** — tightest integration with Google's foundation models (Gemini); strong for BigQuery-native ML workflows
# >
# > All three now offer: AutoML, managed training, model registry, REST endpoints, and MLOps pipelines. The concepts transfer across platforms — the APIs differ but the patterns are identical.
