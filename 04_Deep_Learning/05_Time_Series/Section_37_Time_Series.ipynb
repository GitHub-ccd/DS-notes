# %% [markdown]
# # Section 37 — Time Series
#
# [S37_07_time_series_section_intro.ipynb](./S37_07_time_series_section_intro.ipynb)
#
# [S37_01_introduction_to_time_series.ipynb](./S37_01_introduction_to_time_series.ipynb)
# Datetime indexing in pandas, resampling, rolling windows
#
# [S37_02_managing_time_series_data_lab.ipynb](./S37_02_managing_time_series_data_lab.ipynb)
#
# [S37_10_visualizing_time_series_data_lab.ipynb](./S37_10_visualizing_time_series_data_lab.ipynb)
#
# [S37_09_types_of_trends.ipynb](./S37_09_types_of_trends.ipynb)
# Trend, seasonality, cyclicality, irregular variation
#
# [S37_05_testing_for_trends_lab.ipynb](./S37_05_testing_for_trends_lab.ipynb)
#
# [S37_04_removing_trends.ipynb](./S37_04_removing_trends.ipynb)
# Differencing and detrending to achieve stationarity
#
# [S37_03_removing_trends_lab.ipynb](./S37_03_removing_trends_lab.ipynb)
#
# [S37_06_time_series_decomposition.ipynb](./S37_06_time_series_decomposition.ipynb)
# Additive vs multiplicative decomposition — `statsmodels.tsa.seasonal.seasonal_decompose`
#
# [S37_08_time_series_section_recap.ipynb](./S37_08_time_series_section_recap.ipynb)
