# %% [markdown]
# # Section 21 — Object-Oriented Programming
#
# [S21_06_introduction_to_object_orientation.ipynb](./S21_06_introduction_to_object_orientation.ipynb)
# Introduction to OOP concepts and why they matter
#
# [S21_02_classes_and_instances.ipynb](./S21_02_classes_and_instances.ipynb)
# Defining classes, instantiation, `__init__`
#
# [S21_01_classes_and_instances_lab.ipynb](./S21_01_classes_and_instances_lab.ipynb)
#
# [S21_04_instance_methods.ipynb](./S21_04_instance_methods.ipynb)
# Defining and calling instance methods
#
# [S21_03_instance_methods_lab.ipynb](./S21_03_instance_methods_lab.ipynb)
#
# [S21_05_instance_variables_lab.ipynb](./S21_05_instance_variables_lab.ipynb)
# Instance vs class variables
