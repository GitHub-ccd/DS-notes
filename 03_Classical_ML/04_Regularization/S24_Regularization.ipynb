# %% [markdown]
# # Section 24 — Regularization & Feature Selection
#
# [S24_06_regularization_intro.ipynb](./S24_06_regularization_intro.ipynb)
# Bias-variance tradeoff and the motivation for regularization
#
# [S24_09_ridge_and_lasso_regression.ipynb](./S24_09_ridge_and_lasso_regression.ipynb)
# - **Ridge (L2):** penalises sum of squared coefficients — shrinks all, drops none
# - **Lasso (L1):** penalises sum of absolute coefficients — performs automatic feature selection
# - Standardisation required before applying either
#
# [S24_08_ridge_and_lasso_regression_lab.ipynb](./S24_08_ridge_and_lasso_regression_lab.ipynb)
#
# [S24_02_feature_and_model_selection_aic_and_bic.ipynb](./S24_02_feature_and_model_selection_aic_and_bic.ipynb)
# AIC and BIC as penalised likelihood criteria for model selection
#
# [S24_03_feature_selection_methods.ipynb](./S24_03_feature_selection_methods.ipynb)
# Feature selection approaches:
# - Domain knowledge
# - Wrapper methods (RFE)
# - Filter methods (correlation, variance threshold)
# - Embedded methods (Lasso, tree importance)
#
# [S24_01_extensions_to_linear_models_lab.ipynb](./S24_01_extensions_to_linear_models_lab.ipynb)
#
# [S24_05_generating_data.ipynb](./S24_05_generating_data.ipynb)
# Synthetic data generation for experiments
#
# [S24_04_generating_data_lab.ipynb](./S24_04_generating_data_lab.ipynb)
#
# [S24_07_regularization_recap.ipynb](./S24_07_regularization_recap.ipynb)
