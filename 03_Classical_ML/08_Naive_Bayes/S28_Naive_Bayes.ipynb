# %% [markdown]
# # Section 28 — Naive Bayes
#
# [S28_01_bayesian_classification_intro.ipynb](./S28_01_bayesian_classification_intro.ipynb)
#
# [S28_03_classifiers_with_bayes.ipynb](./S28_03_classifiers_with_bayes.ipynb)
# - The "naive" assumption: features are conditionally independent given the class
# - Using posterior probabilities to make a classification decision
#
# [S28_07_gaussian_naive_bayes.ipynb](./S28_07_gaussian_naive_bayes.ipynb)
# - Theoretical background
# - Iris dataset example
# - Conditional probability point estimates
# - Multinomial Bayes
# - Class probabilities for observations
#
# [S28_06_gaussian_naive_bayes_lab.ipynb](./S28_06_gaussian_naive_bayes_lab.ipynb)
#
# [S28_05_document_classification_with_naive_bayes.ipynb](./S28_05_document_classification_with_naive_bayes.ipynb)
# Bag-of-words and Naive Bayes for text classification
#
# [S28_04_document_classification_with_naive_bayes_lab.ipynb](./S28_04_document_classification_with_naive_bayes_lab.ipynb)
#
# [S28_02_bayesian_classification_recap.ipynb](./S28_02_bayesian_classification_recap.ipynb)
