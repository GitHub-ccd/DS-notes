# %% [markdown]
# # Section 31 — Support Vector Machines
#
# [S31_05_svm_intro.ipynb](./S31_05_svm_intro.ipynb)
#
# [S31_03_introduction_to_support_vector_machines.ipynb](./S31_03_introduction_to_support_vector_machines.ipynb)
# Maximum-margin hyperplane, support vectors, soft margin (`C` parameter)
#
# [S31_01_building_an_svm_from_scratch_lab.ipynb](./S31_01_building_an_svm_from_scratch_lab.ipynb)
# Linear max-margin and soft-margin classifiers from scratch (note: `cvxpy` LAPACK/BLAS dependency issues may arise)
#
# [S31_02_building_an_svm_using_scikit_learn_lab.ipynb](./S31_02_building_an_svm_using_scikit_learn_lab.ipynb)
# Binary and multi-class SVMs with `sklearn.svm.SVC`
#
# [S31_07_the_kernel_trick.ipynb](./S31_07_the_kernel_trick.ipynb)
# Projecting to higher dimensions implicitly — RBF, polynomial, sigmoid kernels
#
# [S31_04_kernels_in_scikit_learn_lab.ipynb](./S31_04_kernels_in_scikit_learn_lab.ipynb)
#
# [S31_06_svm_recap.ipynb](./S31_06_svm_recap.ipynb)
#
# ---
#
# > **2026 context:** SVMs are less dominant in practice than they were pre-2015 — gradient boosted trees and neural networks outperform them on most tabular and image tasks. They remain useful for small-to-medium datasets with clear margin separation and in high-dimensional spaces (e.g. text classification). SHAP does not have a native fast explainer for SVMs; for explainability on SVM predictions use `shap.KernelExplainer` (model-agnostic, slower) — see [S32_05_shap_explainability.ipynb](../S32_Pipelines/S32_05_shap_explainability.ipynb).
