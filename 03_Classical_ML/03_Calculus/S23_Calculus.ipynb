# %% [markdown]
# # Section 23 — Calculus & Gradient Descent
#
# [S23_02_calculus_introduction.ipynb](./S23_02_calculus_introduction.ipynb)
#
# [S23_06_derivatives_intro.ipynb](./S23_06_derivatives_intro.ipynb)
# Introduction to derivatives — slope as rate of change
#
# [S23_05_derivatives_intro_lab.ipynb](./S23_05_derivatives_intro_lab.ipynb)
#
# [S23_07_derivatives_of_non_linear_functions.ipynb](./S23_07_derivatives_of_non_linear_functions.ipynb)
#
# [S23_13_rules_for_derivatives.ipynb](./S23_13_rules_for_derivatives.ipynb)
# Power rule, chain rule, product rule
#
# [S23_04_derivatives_conclusion.ipynb](./S23_04_derivatives_conclusion.ipynb)
#
# [S23_09_gradient_descent_intro.ipynb](./S23_09_gradient_descent_intro.ipynb)
# Gradient descent as an optimisation algorithm
#
# [S23_11_gradient_descent_step_sizes.ipynb](./S23_11_gradient_descent_step_sizes.ipynb)
# Learning rate, overshooting, convergence
#
# [S23_10_gradient_descent_step_sizes_lab.ipynb](./S23_10_gradient_descent_step_sizes_lab.ipynb)
#
# [S23_08_gradient_descent_in_3d.ipynb](./S23_08_gradient_descent_in_3d.ipynb)
# Partial derivatives and gradient in multiple dimensions
#
# [S23_14_the_gradient_in_gradient_descent.ipynb](./S23_14_the_gradient_in_gradient_descent.ipynb)
#
# [S23_12_gradient_to_cost_function.ipynb](./S23_12_gradient_to_cost_function.ipynb)
# Connecting gradient descent to the RSS/MSE cost function
#
# [S23_01_applying_gradient_descent_lab.ipynb](./S23_01_applying_gradient_descent_lab.ipynb)
#
# [S23_03_calculus_section_recap.ipynb](./S23_03_calculus_section_recap.ipynb)
