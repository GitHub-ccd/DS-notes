# %% [markdown]
# # Section 22 — Linear Algebra
#
# [S22_02_linalg_introduction.ipynb](./S22_02_linalg_introduction.ipynb)
# Vectors, matrices, and why linear algebra underpins ML
#
# [S22_11_lingalg_motivation.ipynb](./S22_11_lingalg_motivation.ipynb)
#
# [S22_09_lingalg_linear_equations.ipynb](./S22_09_lingalg_linear_equations.ipynb)
# Systems of linear equations and their geometric interpretation
#
# [S22_10_lingalg_linear_equations_quiz.ipynb](./S22_10_lingalg_linear_equations_quiz.ipynb)
#
# [S22_12_scalars_vectors_matrices_tensors_codealong.ipynb](./S22_12_scalars_vectors_matrices_tensors_codealong.ipynb)
# Scalars, vectors, matrices, tensors — numpy representations
#
# [S22_03_linalg_mat_multiplication_codealong.ipynb](./S22_03_linalg_mat_multiplication_codealong.ipynb)
# Matrix multiplication rules and numpy implementation
#
# [S22_07_lineq_numpy_codealong.ipynb](./S22_07_lineq_numpy_codealong.ipynb)
# Solving linear equations with numpy
#
# [S22_08_lineq_numpy_lab.ipynb](./S22_08_lineq_numpy_lab.ipynb)
#
# [S22_04_linalg_regression_codealong.ipynb](./S22_04_linalg_regression_codealong.ipynb)
# Linear regression as a matrix equation — the normal equation
#
# [S22_05_linalg_regression_lab.ipynb](./S22_05_linalg_regression_lab.ipynb)
#
# [S22_01_computational_complexity.ipynb](./S22_01_computational_complexity.ipynb)
# Big-O notation and complexity of matrix operations
#
# [S22_06_linalg_section_recap.ipynb](./S22_06_linalg_section_recap.ipynb)
