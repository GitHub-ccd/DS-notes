# %% [markdown]
# # Section 26 — MLE & Logistic Regression Deep Dive
#
# [S26_06_mle_logistic_reg_intro.ipynb](./S26_06_mle_logistic_reg_intro.ipynb)
#
# [S26_08_mle_review.ipynb](./S26_08_mle_review.ipynb)
# Maximum Likelihood Estimation — finding parameters that maximise the likelihood of observed data
#
# [S26_07_mle_logistic_regression.ipynb](./S26_07_mle_logistic_regression.ipynb)
# Log-likelihood as the cost function for logistic regression
#
# [S26_03_gradient_descent_review.ipynb](./S26_03_gradient_descent_review.ipynb)
# Gradient descent revisited in the context of MLE optimisation
#
# [S26_02_gradient_descent_lab.ipynb](./S26_02_gradient_descent_lab.ipynb)
#
# [S26_01_coding_logistic_regression_from_scratch.ipynb](./S26_01_coding_logistic_regression_from_scratch.ipynb)
# Implementing logistic regression without sklearn
#
# [S26_04_logistic_regression_model_comparisons_lab.ipynb](./S26_04_logistic_regression_model_comparisons_lab.ipynb)
#
# [S26_05_mle_log_reg_recap.ipynb](./S26_05_mle_log_reg_recap.ipynb)
