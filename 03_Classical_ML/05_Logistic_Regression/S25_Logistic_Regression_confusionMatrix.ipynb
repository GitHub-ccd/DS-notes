# %% [markdown]
# # Section 25 — Logistic Regression & Classification Metrics
#
# [S25_10_logistic_regression_intro.ipynb](./S25_10_logistic_regression_intro.ipynb)
# Introduces logistic regression, ROC/AUC, and class imbalance
#
# [S25_06_intro_to_supervised_learning.ipynb](./S25_06_intro_to_supervised_learning.ipynb)
# High-level overview of supervised vs unsupervised learning
#
# [S25_07_linear_to_logistic_regression.ipynb](./S25_07_linear_to_logistic_regression.ipynb)
# Sigmoid function, log-odds, and the salaries worked example
#
# [S25_09_logistic_regression_in_scikit_learn.ipynb](./S25_09_logistic_regression_in_scikit_learn.ipynb)
# Normalisation → train/test split → fit/predict workflow in sklearn
#
# [S25_08_logistic_regression_in_scikit_learn_lab.ipynb](./S25_08_logistic_regression_in_scikit_learn_lab.ipynb)
#
# [S25_03_confusion_matrices.ipynb](./S25_03_confusion_matrices.ipynb)
# TP/TN/FP/FN — evaluating any classifier
#
# [S25_14_visualizing_confusion_matrices_lab.ipynb](./S25_14_visualizing_confusion_matrices_lab.ipynb)
#
# [S25_05_evaluation_metrics.ipynb](./S25_05_evaluation_metrics.ipynb)
# - **Precision** and **Recall** tradeoff
# - **F1-score** = harmonic mean of precision and recall
# - Use `classification_report` for a full summary
#
# [S25_04_evaluating_logistic_regression_models_lab.ipynb](./S25_04_evaluating_logistic_regression_models_lab.ipynb)
# Cancer risk dataset — utility functions for evaluation metrics
#
# [S25_13_roc_curves_and_auc.ipynb](./S25_13_roc_curves_and_auc.ipynb)
# TPR vs FPR across thresholds — AUC of 1.0 = perfect, 0.5 = random
#
# [S25_12_roc_curves_and_auc_lab.ipynb](./S25_12_roc_curves_and_auc_lab.ipynb)
#
# [S25_02_class_imbalance_problems.ipynb](./S25_02_class_imbalance_problems.ipynb)
# Oversampling minority / undersampling majority — **SMOTE** (Synthetic Minority Oversampling)
#
# [S25_01_class_imbalance_problems_lab.ipynb](./S25_01_class_imbalance_problems_lab.ipynb)
# Credit card fraud example with sklearn's SMOTE
#
# [S25_11_logistic_regression_section_recap.ipynb](./S25_11_logistic_regression_section_recap.ipynb)
