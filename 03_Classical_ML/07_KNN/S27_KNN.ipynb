# %% [markdown]
# # Section 27 — K-Nearest Neighbors
#
# [S27_06_knn_intro.ipynb](./S27_06_knn_intro.ipynb)
#
# [S27_02_distance_metrics.ipynb](./S27_02_distance_metrics.ipynb)
# - Manhattan distance
# - Euclidean distance
# - Minkowski distance (generalisation of both)
#
# [S27_01_distance_metrics_lab.ipynb](./S27_01_distance_metrics_lab.ipynb)
#
# [S27_05_k_nearest_neighbors.ipynb](./S27_05_k_nearest_neighbors.ipynb)
# KNN algorithm, majority vote classification, model evaluation
#
# [S27_04_k_nearest_neighbors_lab.ipynb](./S27_04_k_nearest_neighbors_lab.ipynb)
#
# [S27_03_finding_the_best_value_for_k.ipynb](./S27_03_finding_the_best_value_for_k.ipynb)
# K, overfitting, and underfitting — the bias-variance tradeoff for K
#
# [S27_09_knn_with_scikit_learn.ipynb](./S27_09_knn_with_scikit_learn.ipynb)
# KNN in sklearn — best practices (scaling, cross-validation)
#
# [S27_08_knn_with_scikit_learn_lab.ipynb](./S27_08_knn_with_scikit_learn_lab.ipynb)
#
# [S27_07_knn_recap.ipynb](./S27_07_knn_recap.ipynb)
